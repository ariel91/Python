# %% [markdown]
# # Intro to Pandas
# Pandas es una libreria para el analisis datos que permite hacer manipulaciones al estilod e Excel: agrupar, resumir, hacer tablas pivotes etc. de diferentes fuentes (bases de datos, archivos json, csv, html, excel). abmien permite visualizar datos utilizando matplotlib.
#
# Es una libereria optimizada para el analisis de largas cantidades de informacion.

# %%
import pandas as pd
# %matplotlib inline

# %%
dataframe = pd.read_excel('libroEstudiantes.xlsx')

# %%
dataframe['nota'].plot()

# %%
criterio = dataframe['nota']>=100

# %%
dataframe.head(1)
# Out:
#    numero         carnet                             nombre  columna  nota  \
# 0       1  3476369850101  Anthony Williams Garcia Cordonero        0    50
#
#    c2  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0   0        0.25          88          96         8.4         8.65
#
#    Unnamed: 11  Unnamed: 12
# 0            0         8.65

# %%
dataframe[criterio]['nombre']
# Out:
# 113                        Manfred Giron
# 114     Estephany Gabriela Mayen de León
# 115                       Christian Cruz
# 118              Edvin Gerardo DeLa Cruz
# 122        Abdel Abelardo Chojolán Colop
# 123               Juan Jose Gomez Franco
# 129           Oscar Raul Olivares Ovando
# 133              David Roberto Car Camey
# 134                      Elvin Cervantes
# 138    Wilson Orlando Contreras castillo
# 142      Rolando Estuardo Subuyuj Juarez
# 143                       daniel ramirez
# Name: nombre, dtype: object

# %%
import os
archivos = os.listdir()
for archivo in archivos:
    if 'xlsx' in archivo and '~$' not in archivo:
        print(archivo)
# Out:
# libroEstudiantes.xlsx

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p15',
# ...
